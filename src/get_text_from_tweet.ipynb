# %%
from selenium import webdriver
import re
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import time

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
#chrome_options.add_argument('--headless')  #ẩn cửa sổ chrome
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument("--disable-extensions");
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument('--disable-features=VizDisplayCompositor')
chrome_options.add_argument("--window-size=1920,1080")
driver = webdriver.Chrome(options=chrome_options)

# %%
tweet_url_request = "https://twitter.com/ThePopTingz/status/1676446921307594752?s=20"

tweet_url = "https://publish.twitter.com/?query=" +tweet_url_request
tweet_url
# Out:
# 'https://publish.twitter.com/?query=https://twitter.com/ThePopTingz/status/1676446921307594752?s=20'

# %%
driver.get(tweet_url)

# %%
time.sleep(5)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
text = soup.find('div', class_='WidgetConfigurator-preview').text
text
# Out:
# 'An Echelon Insights poll revealed that Taylor Swift is the third person Americans most want as president of the United States.In the survey, people were asked who they would vote for president if the election were today, Taylor Swift was the third most mentioned:1. Trump… pic.twitter.com/gZbeXBe4j4— Pop Tingz (@ThePopTingz) July 5, 2023\n'

# %%
print(soup.prettify())
# Out:
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Twitter Publish
#   </title>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimal-ui" name="viewport"/>
#   <link href="//abs.twimg.com/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="//ton.twimg.com/syndication/publish/7713336201b2a/css/publish.css" rel="stylesheet" type="text/css"/>
#   <meta content="off" name="twitter:widgets:autoload"/>
#   <script charset="utf-8" src="https://platform.twitter.com/js/tweet.b81b6d7af2d75db873cff6099e4f433a.js">
#   </script>
#  </head>
#  <body style="min-height: 653px;">
#   <div id="app-root">
#    <div>
#     <header class="PublishHeader is-shrinkDisabled" id="top">
#      <div class="PublishHeader-content">
#       <div class="u-cf">
#        <h1 class="PublishHeader-brand">
#         <a class="u-textInheritColor" href="/#">
#          <span class="PublishHeader-logo Icon Icon--twitter">
# ...

# %% [markdown]
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">.<a href="https://twitter.com/BLACKPINK?ref_src=twsrc%5Etfw">@BLACKPINK</a> aren&#39;t just one of the biggest K-pop bands in the world - they&#39;re one of the WORLD’S BIGGEST bands full stop. - BBC News <a href="https://t.co/XfKoXavOrj">pic.twitter.com/XfKoXavOrj</a></p>&mdash; BLΛCKPIИK GLOBAL FANBASE (@BLACKPINKGLOBAL) <a href="https://twitter.com/BLACKPINKGLOBAL/status/1675757597373128704?ref_src=twsrc%5Etfw">July 3, 2023</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
